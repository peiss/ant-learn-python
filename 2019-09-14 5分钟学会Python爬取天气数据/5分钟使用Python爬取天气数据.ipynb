# %% [markdown]
# # 5分钟使用Python爬取天气数据

# %% [markdown]
# 爬取网站的步骤：
# 1. 设定爬取目标
#    * 目标网站：2345天气预报网 http://tianqi.2345.com
#    * 目标数据：北京2018年全年天气预报数据
# 2. 分析目标网站
#    * 待爬取页面：http://tianqi.2345.com/wea_history/54511.htm
#    * 待爬取数据：数据在js里面，http://tianqi.2345.com/t/wea_history/js/201906/54511_201906.js
# 3. 批量下载js文件
#    * 使用requests库实现下载，官网：https://2.python-requests.org//zh_CN/latest/user/quickstart.html
# 4. 实现返回的javascript解析，得到目标数据
#    * 对于javascript的json如何解析？
# 5. 将结果数据存储
#    * 将数据结果存储成csv格式，方便后续数据分析

# %% [markdown]
# ## 1、构造待爬取的月份列表

# %%
# 构造2018全年的月份列表
year = 2018
months = ["%d%02d"%(year, month+1) for month in range(12)]

# %%
months
# Out:
# ['201801',
#  '201802',
#  '201803',
#  '201804',
#  '201805',
#  '201806',
#  '201807',
#  '201808',
#  '201809',
#  '201810',
#  '201811',
#  '201812']

# %% [markdown]
# ## 2、构造待爬取的JS的URL列表

# %%
todo_urls = [
    f"http://tianqi.2345.com/t/wea_history/js/{month}/54511_{month}.js"
    for month in months
]

# %%
todo_urls
# Out:
# ['http://tianqi.2345.com/t/wea_history/js/201801/54511_201801.js',
#  'http://tianqi.2345.com/t/wea_history/js/201802/54511_201802.js',
#  'http://tianqi.2345.com/t/wea_history/js/201803/54511_201803.js',
#  'http://tianqi.2345.com/t/wea_history/js/201804/54511_201804.js',
#  'http://tianqi.2345.com/t/wea_history/js/201805/54511_201805.js',
#  'http://tianqi.2345.com/t/wea_history/js/201806/54511_201806.js',
#  'http://tianqi.2345.com/t/wea_history/js/201807/54511_201807.js',
#  'http://tianqi.2345.com/t/wea_history/js/201808/54511_201808.js',
#  'http://tianqi.2345.com/t/wea_history/js/201809/54511_201809.js',
#  'http://tianqi.2345.com/t/wea_history/js/201810/54511_201810.js',
#  'http://tianqi.2345.com/t/wea_history/js/201811/54511_201811.js',
#  'http://tianqi.2345.com/t/wea_history/js/201812/54511_201812.js']

# %% [markdown]
# ## 3、批量下载数据

# %%
import requests

datas = []
for url in todo_urls:
    r = requests.get(url)
    if r.status_code!=200:
        raise Exception()
    # 去除javascript前后的字符串，得到一个js格式的JSON
    data = r.text.lstrip("var weather_str=").rstrip(";")
    datas.append(data)

# %%
datas[0]
# Out:
# "{city:'北京',tqInfo:[{ymd:'2018-01-01',bWendu:'3℃',yWendu:'-6℃',tianqi:'晴~多云',fengxiang:'东北风',fengli:'1-2级',aqi:'59',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-02',bWendu:'2℃',yWendu:'-5℃',tianqi:'阴~多云',fengxiang:'东北风',fengli:'1-2级',aqi:'49',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-03',bWendu:'2℃',yWendu:'-5℃',tianqi:'多云',fengxiang:'北风',fengli:'1-2级',aqi:'28',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-04',bWendu:'0℃',yWendu:'-8℃',tianqi:'阴',fengxiang:'东北风',fengli:'1-2级',aqi:'28',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-05',bWendu:'3℃',yWendu:'-6℃',tianqi:'多云~晴',fengxiang:'西北风',fengli:'1-2级',aqi:'50',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-06',bWendu:'2℃',yWendu:'-5℃',tianqi:'多云~阴',fengxiang:'西南风',fengli:'1-2级',aqi:'32',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-07',bWendu:'2℃',yWendu:'-4℃',tianqi:'阴~多云',fengxiang:'西南风',fengli:'1-2级',aqi:'59',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-08',bWendu:'2℃',yWendu:'-6℃',tianqi:'晴',fengxiang:'西北风',fengli:'4-5级',aqi:'50',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-09',bWendu:'1℃',yWendu:'-8℃',tianqi:'晴',fengxiang:'西北风',fengli:'3-4级',aqi:'34',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-10',bWendu:'-2℃',yWendu:'-10℃',tianqi:'晴',fengxiang:'西北风',fengli:'1-2级',aqi:'26',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-11',bWendu:'-1℃',yWendu:'-10℃',tianqi:'晴',fengxiang:'北风',fengli:'1-2级',aqi:'24',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-12',bWendu:'2℃',yWendu:'-8℃',tianqi:'晴',fengxiang:'西南风',fengli:'1-2级',aqi:'75',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-13',bWendu:'3℃',yWendu:'-7℃',tianqi:'多云',fengxiang:'南风',fengli:'1-2级',aqi:'126',aqiInfo:'轻度污染',aqiLevel:'3'},{ymd:'2018-01-14',bWendu:'6℃',yWendu:'-5℃',tianqi:'晴~多云',fengxiang:'西北风',fengli:'1-2级',aqi:'187',aqiInfo:'中度污染',aqiLevel:'4'},{ymd:'2018-01-15',bWendu:'2℃',yWendu:'-5℃',tianqi:'阴',fengxiang:'东南风',fengli:'1-2级',aqi:'47',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-16',bWendu:'4℃',yWendu:'-5℃',tianqi:'多云',fengxiang:'南风',fengli:'1-2级',aqi:'112',aqiInfo:'轻度污染',aqiLevel:'3'},{ymd:'2018-01-17',bWendu:'6℃',yWendu:'-7℃',tianqi:'多云~晴',fengxiang:'西北风',fengli:'1-2级',aqi:'82',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-18',bWendu:'5℃',yWendu:'-6℃',tianqi:'晴',fengxiang:'西南风',fengli:'1-2级',aqi:'80',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-19',bWendu:'7℃',yWendu:'-4℃',tianqi:'晴',fengxiang:'南风',fengli:'1-2级',aqi:'115',aqiInfo:'轻度污染',aqiLevel:'3'},{ymd:'2018-01-20',bWendu:'3℃',yWendu:'-6℃',tianqi:'晴~多云',fengxiang:'东风',fengli:'1-2级',aqi:'64',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-21',bWendu:'0℃',yWendu:'-5℃',tianqi:'阴~小雪',fengxiang:'东北风',fengli:'1-2级',aqi:'63',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-22',bWendu:'-3℃',yWendu:'-10℃',tianqi:'小雪~多云',fengxiang:'东风',fengli:'1-2级',aqi:'47',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-23',bWendu:'-4℃',yWendu:'-12℃',tianqi:'晴',fengxiang:'西北风',fengli:'3-4级',aqi:'31',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-24',bWendu:'-4℃',yWendu:'-11℃',tianqi:'晴',fengxiang:'西南风',fengli:'1-2级',aqi:'34',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-25',bWendu:'-3℃',yWendu:'-11℃',tianqi:'多云',fengxiang:'东北风',fengli:'1-2级',aqi:'27',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-26',bWendu:'-3℃',yWendu:'-10℃',tianqi:'晴~多云',fengxiang:'南风',fengli:'1-2级',aqi:'39',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-27',bWendu:'-1℃',yWendu:'-9℃',tianqi:'多云',fengxiang:'南风',fengli:'1-2级',aqi:'105',aqiInfo:'轻度污染',aqiLevel:'3'},{ymd:'2018-01-28',bWendu:'-1℃',yWendu:'-9℃',tianqi:'晴',fengxiang:'西北风',fengli:'3-4级',aqi:'55',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-29',bWendu:'1℃',yWendu:'-8℃',tianqi:'晴',fengxiang:'西北风',fengli:'1-2级',aqi:'57',aqiInfo:'良',aqiLevel:'2'},{ymd:'2018-01-30',bWendu:'4℃',yWendu:'-7℃',tianqi:'晴',fengxiang:'西北风',fengli:'1-2级',aqi:'36',aqiInfo:'优',aqiLevel:'1'},{ymd:'2018-01-31',bWendu:'3℃',yWendu:'-8℃',tianqi:'晴',fengxiang:'西南风',fengli:'1-2级',aqi:'60',aqiInfo:'良',aqiLevel:'2'},{}],maxWendu:'7（2018-01-19）',minWendu:'-12（2018-01-23）',avgbWendu:'1',avgyWendu:'-7',maxAqi:'187',minAqi:'24',avgAqi:'61',maxAqiInfo:'中度污染',maxAqiDate:'01月14日',maxAqiLevel:'4',minAqiInfo:'空气优',minAqiDate:'01月11日',minAqiLevel: ...

# %% [markdown]
# ## 4、解析JavaScript返回的数据

# %%
### 注意，这里的json是javascript格式，不能用标准库json解析
import json
json.loads(datas[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-b1ec799a630b> in <module>
#       1 ### 注意，这里的json是javascript格式，不能用标准库json解析
#       2 import json
# ----> 3 json.loads(datas[0])
#
# d:\appdata\python37\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# d:\appdata\python37\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# d:\appdata\python37\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %% [markdown]
# ***介绍模块：demjson***
# 地址：https://pypi.org/project/demjson/2.2.4/
# 理由：
#     It is especially useful for
#     error checking
#     or ***for parsing JavaScript data***
#     which may not strictly be valid JSON data.

# %%
import demjson

# %%
demjson.decode(datas[0])
# Out:
# {'city': '北京',
#  'tqInfo': [{'ymd': '2018-01-01',
#    'bWendu': '3℃',
#    'yWendu': '-6℃',
#    'tianqi': '晴~多云',
#    'fengxiang': '东北风',
#    'fengli': '1-2级',
#    'aqi': '59',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-02',
#    'bWendu': '2℃',
#    'yWendu': '-5℃',
#    'tianqi': '阴~多云',
#    'fengxiang': '东北风',
#    'fengli': '1-2级',
#    'aqi': '49',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-03',
#    'bWendu': '2℃',
#    'yWendu': '-5℃',
#    'tianqi': '多云',
#    'fengxiang': '北风',
#    'fengli': '1-2级',
#    'aqi': '28',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-04',
#    'bWendu': '0℃',
#    'yWendu': '-8℃',
#    'tianqi': '阴',
#    'fengxiang': '东北风',
#    'fengli': '1-2级',
#    'aqi': '28',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-05',
#    'bWendu': '3℃',
#    'yWendu': '-6℃',
#    'tianqi': '多云~晴',
#    'fengxiang': '西北风',
#    'fengli': '1-2级',
#    'aqi': '50',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-06',
#    'bWendu': '2℃',
#    'yWendu': '-5℃',
#    'tianqi': '多云~阴',
#    'fengxiang': '西南风',
#    'fengli': '1-2级',
#    'aqi': '32',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-07',
#    'bWendu': '2℃',
#    'yWendu': '-4℃',
#    'tianqi': '阴~多云',
#    'fengxiang': '西南风',
#    'fengli': '1-2级',
#    'aqi': '59',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-08',
#    'bWendu': '2℃',
#    'yWendu': '-6℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '4-5级',
#    'aqi': '50',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-09',
#    'bWendu': '1℃',
#    'yWendu': '-8℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '3-4级',
#    'aqi': '34',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-10',
#    'bWendu': '-2℃',
#    'yWendu': '-10℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '1-2级',
#    'aqi': '26',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-11',
#    'bWendu': '-1℃',
#    'yWendu': '-10℃',
#    'tianqi': '晴',
#    'fengxiang': '北风',
#    'fengli': '1-2级',
#    'aqi': '24',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-12',
#    'bWendu': '2℃',
#    'yWendu': '-8℃',
#    'tianqi': '晴',
#    'fengxiang': '西南风',
#    'fengli': '1-2级',
#    'aqi': '75',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-13',
#    'bWendu': '3℃',
#    'yWendu': '-7℃',
#    'tianqi': '多云',
#    'fengxiang': '南风',
#    'fengli': '1-2级',
#    'aqi': '126',
#    'aqiInfo': '轻度污染',
#    'aqiLevel': '3'},
#   {'ymd': '2018-01-14',
#    'bWendu': '6℃',
#    'yWendu': '-5℃',
#    'tianqi': '晴~多云',
#    'fengxiang': '西北风',
#    'fengli': '1-2级',
#    'aqi': '187',
#    'aqiInfo': '中度污染',
#    'aqiLevel': '4'},
#   {'ymd': '2018-01-15',
#    'bWendu': '2℃',
#    'yWendu': '-5℃',
#    'tianqi': '阴',
#    'fengxiang': '东南风',
#    'fengli': '1-2级',
#    'aqi': '47',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-16',
#    'bWendu': '4℃',
#    'yWendu': '-5℃',
#    'tianqi': '多云',
#    'fengxiang': '南风',
#    'fengli': '1-2级',
#    'aqi': '112',
#    'aqiInfo': '轻度污染',
#    'aqiLevel': '3'},
#   {'ymd': '2018-01-17',
#    'bWendu': '6℃',
#    'yWendu': '-7℃',
#    'tianqi': '多云~晴',
#    'fengxiang': '西北风',
#    'fengli': '1-2级',
#    'aqi': '82',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-18',
#    'bWendu': '5℃',
#    'yWendu': '-6℃',
#    'tianqi': '晴',
#    'fengxiang': '西南风',
#    'fengli': '1-2级',
#    'aqi': '80',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-19',
#    'bWendu': '7℃',
#    'yWendu': '-4℃',
#    'tianqi': '晴',
#    'fengxiang': '南风',
#    'fengli': '1-2级',
#    'aqi': '115',
#    'aqiInfo': '轻度污染',
#    'aqiLevel': '3'},
#   {'ymd': '2018-01-20',
#    'bWendu': '3℃',
#    'yWendu': '-6℃',
#    'tianqi': '晴~多云',
#    'fengxiang': '东风',
#    'fengli': '1-2级',
#    'aqi': '64',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-21',
#    'bWendu': '0℃',
#    'yWendu': '-5℃',
#    'tianqi': '阴~小雪',
#    'fengxiang': '东北风',
#    'fengli': '1-2级',
#    'aqi': '63',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-22',
#    'bWendu': '-3℃',
#    'yWendu': '-10℃',
#    'tianqi': '小雪~多云',
#    'fengxiang': '东风',
#    'fengli': '1-2级',
#    'aqi': '47',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-23',
#    'bWendu': '-4℃',
#    'yWendu': '-12℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '3-4级',
#    'aqi': '31',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-24',
#    'bWendu': '-4℃',
#    'yWendu': '-11℃',
#    'tianqi': '晴',
#    'fengxiang': '西南风',
#    'fengli': '1-2级',
#    'aqi': '34',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-25',
#    'bWendu': '-3℃',
#    'yWendu': '-11℃',
#    'tianqi': '多云',
#    'fengxiang': '东北风',
#    'fengli': '1-2级',
#    'aqi': '27',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-26',
#    'bWendu': '-3℃',
#    'yWendu': '-10℃',
#    'tianqi': '晴~多云',
#    'fengxiang': '南风',
#    'fengli': '1-2级',
#    'aqi': '39',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-27',
#    'bWendu': '-1℃',
#    'yWendu': '-9℃',
#    'tianqi': '多云',
#    'fengxiang': '南风',
#    'fengli': '1-2级',
#    'aqi': '105',
#    'aqiInfo': '轻度污染',
#    'aqiLevel': '3'},
#   {'ymd': '2018-01-28',
#    'bWendu': '-1℃',
#    'yWendu': '-9℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '3-4级',
#    'aqi': '55',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-29',
#    'bWendu': '1℃',
#    'yWendu': '-8℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '1-2级',
#    'aqi': '57',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {'ymd': '2018-01-30',
#    'bWendu': '4℃',
#    'yWendu': '-7℃',
#    'tianqi': '晴',
#    'fengxiang': '西北风',
#    'fengli': '1-2级',
#    'aqi': '36',
#    'aqiInfo': '优',
#    'aqiLevel': '1'},
#   {'ymd': '2018-01-31',
#    'bWendu': '3℃',
#    'yWendu': '-8℃',
#    'tianqi': '晴',
#    'fengxiang': '西南风',
#    'fengli': '1-2级',
#    'aqi': '60',
#    'aqiInfo': '良',
#    'aqiLevel': '2'},
#   {}],
#  'maxWendu': '7（2018-01-19）',
#  'minWendu': '-12（2018-01-23）',
#  'avgbWendu': '1',
#  'avgyWendu': '-7',
#  'maxAqi': '187',
#  'minAqi': '24',
#  'avgAqi': '61',
#  'maxAqiInfo': '中度污染',
#  'maxAqiDate': '01月14日',
#  'maxAqiLevel': '4',
#  'minAqiInfo': '空气优',
#  'minAqiDate': '01月11日',
#  'minAqiLevel': '1'}

# %%
tqInfos = demjson.decode(datas[0])["tqInfo"]

# %%
tqInfos
# Out:
# [{'ymd': '2018-01-01',
#   'bWendu': '3℃',
#   'yWendu': '-6℃',
#   'tianqi': '晴~多云',
#   'fengxiang': '东北风',
#   'fengli': '1-2级',
#   'aqi': '59',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-02',
#   'bWendu': '2℃',
#   'yWendu': '-5℃',
#   'tianqi': '阴~多云',
#   'fengxiang': '东北风',
#   'fengli': '1-2级',
#   'aqi': '49',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-03',
#   'bWendu': '2℃',
#   'yWendu': '-5℃',
#   'tianqi': '多云',
#   'fengxiang': '北风',
#   'fengli': '1-2级',
#   'aqi': '28',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-04',
#   'bWendu': '0℃',
#   'yWendu': '-8℃',
#   'tianqi': '阴',
#   'fengxiang': '东北风',
#   'fengli': '1-2级',
#   'aqi': '28',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-05',
#   'bWendu': '3℃',
#   'yWendu': '-6℃',
#   'tianqi': '多云~晴',
#   'fengxiang': '西北风',
#   'fengli': '1-2级',
#   'aqi': '50',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-06',
#   'bWendu': '2℃',
#   'yWendu': '-5℃',
#   'tianqi': '多云~阴',
#   'fengxiang': '西南风',
#   'fengli': '1-2级',
#   'aqi': '32',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-07',
#   'bWendu': '2℃',
#   'yWendu': '-4℃',
#   'tianqi': '阴~多云',
#   'fengxiang': '西南风',
#   'fengli': '1-2级',
#   'aqi': '59',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-08',
#   'bWendu': '2℃',
#   'yWendu': '-6℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '4-5级',
#   'aqi': '50',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-09',
#   'bWendu': '1℃',
#   'yWendu': '-8℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '3-4级',
#   'aqi': '34',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-10',
#   'bWendu': '-2℃',
#   'yWendu': '-10℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '1-2级',
#   'aqi': '26',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-11',
#   'bWendu': '-1℃',
#   'yWendu': '-10℃',
#   'tianqi': '晴',
#   'fengxiang': '北风',
#   'fengli': '1-2级',
#   'aqi': '24',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-12',
#   'bWendu': '2℃',
#   'yWendu': '-8℃',
#   'tianqi': '晴',
#   'fengxiang': '西南风',
#   'fengli': '1-2级',
#   'aqi': '75',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-13',
#   'bWendu': '3℃',
#   'yWendu': '-7℃',
#   'tianqi': '多云',
#   'fengxiang': '南风',
#   'fengli': '1-2级',
#   'aqi': '126',
#   'aqiInfo': '轻度污染',
#   'aqiLevel': '3'},
#  {'ymd': '2018-01-14',
#   'bWendu': '6℃',
#   'yWendu': '-5℃',
#   'tianqi': '晴~多云',
#   'fengxiang': '西北风',
#   'fengli': '1-2级',
#   'aqi': '187',
#   'aqiInfo': '中度污染',
#   'aqiLevel': '4'},
#  {'ymd': '2018-01-15',
#   'bWendu': '2℃',
#   'yWendu': '-5℃',
#   'tianqi': '阴',
#   'fengxiang': '东南风',
#   'fengli': '1-2级',
#   'aqi': '47',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-16',
#   'bWendu': '4℃',
#   'yWendu': '-5℃',
#   'tianqi': '多云',
#   'fengxiang': '南风',
#   'fengli': '1-2级',
#   'aqi': '112',
#   'aqiInfo': '轻度污染',
#   'aqiLevel': '3'},
#  {'ymd': '2018-01-17',
#   'bWendu': '6℃',
#   'yWendu': '-7℃',
#   'tianqi': '多云~晴',
#   'fengxiang': '西北风',
#   'fengli': '1-2级',
#   'aqi': '82',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-18',
#   'bWendu': '5℃',
#   'yWendu': '-6℃',
#   'tianqi': '晴',
#   'fengxiang': '西南风',
#   'fengli': '1-2级',
#   'aqi': '80',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-19',
#   'bWendu': '7℃',
#   'yWendu': '-4℃',
#   'tianqi': '晴',
#   'fengxiang': '南风',
#   'fengli': '1-2级',
#   'aqi': '115',
#   'aqiInfo': '轻度污染',
#   'aqiLevel': '3'},
#  {'ymd': '2018-01-20',
#   'bWendu': '3℃',
#   'yWendu': '-6℃',
#   'tianqi': '晴~多云',
#   'fengxiang': '东风',
#   'fengli': '1-2级',
#   'aqi': '64',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-21',
#   'bWendu': '0℃',
#   'yWendu': '-5℃',
#   'tianqi': '阴~小雪',
#   'fengxiang': '东北风',
#   'fengli': '1-2级',
#   'aqi': '63',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-22',
#   'bWendu': '-3℃',
#   'yWendu': '-10℃',
#   'tianqi': '小雪~多云',
#   'fengxiang': '东风',
#   'fengli': '1-2级',
#   'aqi': '47',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-23',
#   'bWendu': '-4℃',
#   'yWendu': '-12℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '3-4级',
#   'aqi': '31',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-24',
#   'bWendu': '-4℃',
#   'yWendu': '-11℃',
#   'tianqi': '晴',
#   'fengxiang': '西南风',
#   'fengli': '1-2级',
#   'aqi': '34',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-25',
#   'bWendu': '-3℃',
#   'yWendu': '-11℃',
#   'tianqi': '多云',
#   'fengxiang': '东北风',
#   'fengli': '1-2级',
#   'aqi': '27',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-26',
#   'bWendu': '-3℃',
#   'yWendu': '-10℃',
#   'tianqi': '晴~多云',
#   'fengxiang': '南风',
#   'fengli': '1-2级',
#   'aqi': '39',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-27',
#   'bWendu': '-1℃',
#   'yWendu': '-9℃',
#   'tianqi': '多云',
#   'fengxiang': '南风',
#   'fengli': '1-2级',
#   'aqi': '105',
#   'aqiInfo': '轻度污染',
#   'aqiLevel': '3'},
#  {'ymd': '2018-01-28',
#   'bWendu': '-1℃',
#   'yWendu': '-9℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '3-4级',
#   'aqi': '55',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-29',
#   'bWendu': '1℃',
#   'yWendu': '-8℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '1-2级',
#   'aqi': '57',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {'ymd': '2018-01-30',
#   'bWendu': '4℃',
#   'yWendu': '-7℃',
#   'tianqi': '晴',
#   'fengxiang': '西北风',
#   'fengli': '1-2级',
#   'aqi': '36',
#   'aqiInfo': '优',
#   'aqiLevel': '1'},
#  {'ymd': '2018-01-31',
#   'bWendu': '3℃',
#   'yWendu': '-8℃',
#   'tianqi': '晴',
#   'fengxiang': '西南风',
#   'fengli': '1-2级',
#   'aqi': '60',
#   'aqiInfo': '良',
#   'aqiLevel': '2'},
#  {}]

# %%
# 解析所有月份的数据
all_datas = []

for data in datas:
    tqInfos = demjson.decode(data)["tqInfo"]
    all_datas.extend([x for x in tqInfos if len(x)>0])

# %%
len(all_datas)
# Out:
# 365

# %% [markdown]
# ## 5、将结果写出到csv文件

# %%
all_datas[0]
# Out:
# {'ymd': '2018-01-01',
#  'bWendu': '3℃',
#  'yWendu': '-6℃',
#  'tianqi': '晴~多云',
#  'fengxiang': '东北风',
#  'fengli': '1-2级',
#  'aqi': '59',
#  'aqiInfo': '良',
#  'aqiLevel': '2'}

# %%
all_datas[0].keys()
# Out:
# dict_keys(['ymd', 'bWendu', 'yWendu', 'tianqi', 'fengxiang', 'fengli', 'aqi', 'aqiInfo', 'aqiLevel'])

# %%
import csv
with open('./beijing_tianqi_2018.csv', 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    
    columns = ['ymd', 'bWendu', 'yWendu', 'tianqi', 'fengxiang', 'fengli', 'aqi', 'aqiInfo', 'aqiLevel']
    writer.writerow(columns)
    
    for data in all_datas:
        writer.writerow([data[column] for column in columns])
